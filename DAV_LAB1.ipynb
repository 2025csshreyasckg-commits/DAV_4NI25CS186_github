# %% [markdown]
# <a href="https://colab.research.google.com/github/2025csshreyasckg-commits/DAV_4NI25CS186_github/blob/main/DAV_LAB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd

# %%
data = {
    "Name":["Anu","Rhaul","Kiran","Priya"],
    "Marks":[45, 67, 98, 62],
    "Attendence":[69, 84, 91, 76]
}
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#     Name  Marks  Attendence
# 0    Anu     45          69
# 1  Rhaul     67          84
# 2  Kiran     98          91
# 3  Priya     62          76

# %%
df.tail()
# Out:
#     Name  Marks  Attendence
# 0    Anu     45          69
# 1  Rhaul     67          84
# 2  Kiran     98          91
# 3  Priya     62          76
