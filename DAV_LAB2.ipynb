# %% [markdown]
# <a href="https://colab.research.google.com/github/2025csshreyasckg-commits/DAV_4NI25CS186_github/blob/main/DAV_LAB2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

data = {
    'Name':['Amit','Bebo','Chetan','Amit','Divya','Ravi'],
    'Age':[25, np.nan, 30, 28, 22, np.nan],
    'Marks':[85, 90, np.nan, 85, 78, 95],
    'City':['Mysuru', 'Mysuru', 'Bengaluru', 'Mysuru', np.nan, 'Delhi']
}

df = pd.DataFrame(data)
print("Dataset:")
df
# Out:
# Dataset:
#      Name   Age  Marks       City
# 0    Amit  25.0   85.0     Mysuru
# 1    Bebo   NaN   90.0     Mysuru
# 2  Chetan  30.0    NaN  Bengaluru
# 3    Amit  28.0   85.0     Mysuru
# 4   Divya  22.0   78.0        NaN
# 5    Ravi   NaN   95.0      Delhi

# %%
print("\nShape of dataset (rows, columns):", df.shape)
print("\nColumn names:",df.columns.tolist())

print("\nData types of each column:")
print(df.dtypes)

print("\nContent info:")
df.info()
# Out:
# Shape of dataset (rows, columns): (6, 4)
#
# Column names: ['Name', 'Age', 'Marks', 'City']
#
# Data types of each column:
# Name      object
# Age      float64
# Marks    float64
# City      object
# dtype: object
#
# Content info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     4 non-null      float64
#  2   Marks   5 non-null      float64
#  3   City    5 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 324.0+ bytes

# %%
print("\ndescriptive statstics (numerical columns):")
print(df.describe())

print("\nMean:\n",df.mean(numeric_only=True))
print("\nMedian:\n",df.median(numeric_only=True))
print("\nMode\n",df.mode(numeric_only=True))
print("\nStandard Deviation\n",df.std(numeric_only=True))
# Out:
# descriptive statstics (numerical columns):
#          Age      Marks
# count   4.00   5.000000
# mean   26.25  86.600000
# std     3.50   6.348228
# min    22.00  78.000000
# 25%    24.25  85.000000
# 50%    26.50  85.000000
# 75%    28.50  90.000000
# max    30.00  95.000000
#
# Mean:
#  Age      26.25
# Marks    86.60
# dtype: float64
#
# Median:
#  Age      26.5
# Marks    85.0
# dtype: float64
#
# Mode
#      Age  Marks
# 0  22.0   85.0
# 1  25.0    NaN
# 2  28.0    NaN
# 3  30.0    NaN
#
# Standard Deviation
#  Age      3.500000
# Marks    6.348228
# dtype: float64

# %%
print("\nMissing values in each column:")
print(df.isnull().sum())
print("\nTotal missing vlues in dataset:",df.isnull().sum().sum())
# Out:
# Missing values in each column:
# Name     0
# Age      2
# Marks    1
# City     1
# dtype: int64
#
# Total missing vlues in dataset: 4

# %%
print("\nDuplicate rows in dataset:")
print(df[df.duplicated()])

print("\nNumber of duplicates rows:",df.duplicated().sum())

print("\nEDA process completed successfully!")
# Out:
# Duplicate rows in dataset:
# Empty DataFrame
# Columns: [Name, Age, Marks, City]
# Index: []
#
# Number of duplicates rows: 0
#
# EDA process completed successfully!
